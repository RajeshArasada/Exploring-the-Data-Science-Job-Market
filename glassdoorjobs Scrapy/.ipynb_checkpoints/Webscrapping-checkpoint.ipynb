s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_0b1af426&cb=1539365891189&jobListingId=2971078739'

# %%
df = pd.read_csv('job_links_ct_main.csv')
df.head()
# Out:
#                                            job_links
# 0  /partner/jobListing.htm?pos=101&ao=128485&s=58...
# 1  /partner/jobListing.htm?pos=101&ao=328832&s=58...
# 2  /partner/jobListing.htm?pos=101&ao=281704&s=58...
# 3  /partner/jobListing.htm?pos=101&ao=4372&s=58&g...
# 4  /partner/jobListing.htm?pos=101&ao=359521&s=58...

# %%
ct = df['job_links'][0]
print (ct)
# Out:
# /partner/jobListing.htm?pos=101&ao=128485&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_c8766c39&cb=1539367530080&jobListingId=2613520827,/partner/jobListing.htm?pos=102&ao=302378&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_781c1f8b&cb=1539367530081&jobListingId=2984256323,/partner/jobListing.htm?pos=103&ao=128485&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_06f3aecc&cb=1539367530082&jobListingId=2978725014,/partner/jobListing.htm?pos=104&ao=371854&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_9898e64b&cb=1539367530082&jobListingId=2914053636,/partner/jobListing.htm?pos=105&ao=396254&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_6c658100&cb=1
# ...

# %%
ct_urls = ct.split(',')
print (len(ct_urls))
print (ct_urls[0])
# Out:
# 30
# /partner/jobListing.htm?pos=101&ao=128485&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_c8766c39&cb=1539367530080&jobListingId=2613520827

# %%
ct_first_url = 'https://www.glassdoor.com'+ ct_urls[0]
print (ct_first_url)
# Out:
# https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=128485&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_c8766c39&cb=1539367530080&jobListingId=2613520827

# %%
df_2 = pd.read_csv('job_links.csv')
df_2.head()
# Out:
#                                            job_links
# 0  /partner/jobListing.htm?pos=101&ao=287248&s=58...
# 1  /partner/jobListing.htm?pos=101&ao=359521&s=58...
# 2  /partner/jobListing.htm?pos=101&ao=404740&s=58...

# %%
ny = df_2['job_links'][2]

# %%
ny_urls = ny.split(',')
print (len(ny_urls))
print (ny_urls[0])
# Out:
# 30
# /partner/jobListing.htm?pos=101&ao=404740&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=L&ist=&ast=L&vt=w&slr=true&rtp=0&aa=1&ea=1&cs=1_5721e5c9&cb=1539368731989&jobListingId=2939228247

# %%
ny_first_url = 'https://www.glassdoor.com'+ ny_urls[0]
print (ny_first_url)
# Out:
# https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=404740&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=L&ist=&ast=L&vt=w&slr=true&rtp=0&aa=1&ea=1&cs=1_5721e5c9&cb=1539368731989&jobListingId=2939228247

# %%
[item for sublist in l for item in sublist]

# %%
#[lst for lst in ct_urls]

#ct_urls = [i.split(',') for i in df['job_links']]
#print (ct_urls)
ct_pages = [lst for lst in df['job_links']]
print (ct_pages)
print(len(ct_pages))
# Out:
# ['/partner/jobListing.htm?pos=101&ao=128485&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_c8766c39&cb=1539367530080&jobListingId=2613520827,/partner/jobListing.htm?pos=102&ao=302378&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_781c1f8b&cb=1539367530081&jobListingId=2984256323,/partner/jobListing.htm?pos=103&ao=128485&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_06f3aecc&cb=1539367530082&jobListingId=2978725014,/partner/jobListing.htm?pos=104&ao=371854&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1
s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_bb78b61a&cb=1539365892707&jobListingId=2987508265,/partner/jobListing.htm?pos=125&ao=328832&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_caf1857e&cb=1539365892708&jobListingId=2987923704,/partner/jobListing.htm?pos=126&ao=133122&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_c28ed63f&cb=1539365892709&jobListingId=2987508283,/partner/jobListing.htm?pos=127&ao=4120&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_54c2bf36&cb=1539365892710&jobListingId=2918855876,/partner/jobListing.htm?pos=128&ao=173354&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_db897366&cb=1539365892711&jobListingId=2983914177,/partner/jobListing.htm?pos=129&ao=206161&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_2368e406&cb=1539365892713&jobListingId=2962388337,/partner/jobListing.htm?pos=130&ao=359521&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_52c40322&cb=1539365892714&jobListingId=2988539911'

# %%
delaware = delaware.split(',')
print(len(delaware))
# Out:
# 30

# %%
delaware[0]
# Out:
# '/partner/jobListing.htm?pos=101&ao=328832&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_fe7094dd&cb=1539365892680&jobListingId=2987923699'

# %%
url_del_ = 'https://www.glassdoor.com'+ delaware[0]
print (url_del_)
# Out:
# https://www.glassdoor.com/partner/jobListing.htm?pos=101&ao=328832&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_fe7094dd&cb=1539365892680&jobListingId=2987923699

# %%
start_urls = 'https://www.glassdoor.com/Job/new-jersey-data-science-jobs-SRCH_IL.0,10_IS39_KO11,23_IP1.htm'

# %%
[start_urls.replace('IP1', 'IP{}'.format(i) for i in range(1,3))]
# Out:
#   File "<ipython-input-77-2dd202828a68>", line 1
#     [start_urls.replace('IP1', 'IP{}'.format(i) for i in range(1,3))]
#                        ^
# SyntaxError: Generator expression must be parenthesized if not sole argument

# %%
following_urls = [start_urls.replace('IP1',x) for x in ['IP{}'.format(i) for i in range(1,3)]]# range(1, (page_number +1))[:10]) #{}.htm'.format(i) for i in range(1, (page_number +1))][:10]
following_urls

# %%
df_03 = pd.read_csv('job_links.csv')

nj_page_1 = df_03['job_links'][0]

nj_page_1_urls = nj_page_1.split(',')
print (len(nj_page_1_urls))
print (nj_page_1_urls[0])

nj_page_1_first_url = 'https://www.glassdoor.com'+ nj_page_1_urls[0]
print (nj_first_url)
# Out:
# 30
# /partner/jobListing.htm?pos=301&ao=320811&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_d11a0a41&cb=1539374103720&jobListingId=2948601147
# https://www.glassdoor.com/partner/jobListing.htm?pos=301&ao=320811&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_d11a0a41&cb=1539374103720&jobListingId=2948601147

# %%
nj_page_2 = df_03['job_links'][1]

nj_page_2_urls = nj_page_2.split(',')
print (len(nj_page_2_urls))
print (nj_page_2_urls[0])

nj_page_2_first_url = 'https://www.glassdoor.com'+ nj_page_2_urls[0]
print (nj_page_2_first_url)
# Out:
# 30
# /partner/jobListing.htm?pos=3001&ao=68087&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_f623ff2d&cb=1539374106570&jobListingId=2929541254
# https://www.glassdoor.com/partner/jobListing.htm?pos=3001&ao=68087&s=58&guid=1234567890abcdef1234567890abcdef&src=GD_JOB_AD&t=SR&extid=1&exst=OL&ist=&ast=OL&vt=w&slr=true&rtp=0&cs=1_f623ff2d&cb=1539374106570&jobListingId=2929541254
